# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import

# %%
# %matplotlib inline

# %%
df = pd.read_csv('car-clean-mpg.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 392 entries, 0 to 391
# Data columns (total 9 columns):
# mpg             392 non-null float64
# cylinders       392 non-null int64
# displacement    392 non-null float64
# horsepower      392 non-null float64
# weight          392 non-null float64
# acceleration    392 non-null float64
# model_year      392 non-null int64
# origin          392 non-null int64
# car_name        392 non-null object
# dtypes: float64(5), int64(3), object(1)
# memory usage: 27.6+ KB

# %%
df.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0  3504.0          12.0
# 1  15.0          8         350.0       165.0  3693.0          11.5
# 2  18.0          8         318.0       150.0  3436.0          11.0
# 3  16.0          8         304.0       150.0  3433.0          12.0
# 4  17.0          8         302.0       140.0  3449.0          10.5
#
#    model_year  origin                   car_name
# 0          70       1  chevrolet chevelle malibu
# 1          70       1          buick skylark 320
# 2          70       1         plymouth satellite
# 3          70       1              amc rebel sst
# 4          70       1                ford torino

# %%
sns.pairplot(df.drop('car_name', axis=1))

# %%
sns.pairplot(df[['mpg', 'cylinders', 'horsepower']])

# %%
sns.distplot(df['mpg'])

# %%
sns.distplot(df['mpg'], kde=False)

# %%
sns.jointplot(x=df['horsepower'], y=df['mpg'],kind="hex", color="#4CB391")

# %%
sns.jointplot(x=df['horsepower'], y=df['mpg'], color="#4CB391")
